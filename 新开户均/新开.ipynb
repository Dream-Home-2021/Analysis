# %%
from Common.Common import Filter
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1124\3802188886.py in <module>
# ----> 1 from Common.Common import Filter
#       2 import pandas as pd
#
# ImportError: cannot import name 'Filter' from 'Common.Common' (C:\FLS\JOB\消费模板\Common\Common.py)

# %%
df = pd.read_excel('../通讯录.xlsx', usecols=[0, 1, 2, 3])
print(df)
# Out:
#                   管理员      部门       组别      客服
# 0              12t040    新开部门     新开一部      注册
# 1               12t00    大客部门  大客KOL客服      陈沅
# 2     12t097，feedkf01    维护部门     维护一部     俞培培
# 3              12t021    大客部门     行业二部     陈金锐
# 4        xmpinzhuan01     品牌部      品牌组     杨丹凤
# ..                ...     ...      ...     ...
# 230  xmfq02，xmkuang03      框架       框架      框架
# 231     xmfq05，xmfq08      框架       框架      框架
# 232     xmds01，xmfq08      框架       框架      框架
# 233             xm005    新开部门     新开一部      叶惠
# 234            12t054  行发维护大区   信息流VIP  厦门自营电商
#
# [235 rows x 4 columns]

# %%
a = Filter(df)
opennew = a.filter_Object('组别', ['新开部门', '新开一部', '新开二部', '新开三部', '泉州新开', '漳州新开'])
print(opennew)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1124\2350602041.py in <module>
# ----> 1 a = Filter(df)
#       2 opennew = a.filter_Object('组别', ['新开部门', '新开一部', '新开二部', '新开三部', '泉州新开', '漳州新开'])
#       3 print(opennew)
#
# NameError: name 'Filter' is not defined

# %%
filter_instance = Filter(df)

# Example 1: Filtering rows where column 'A' is either 'a' or 'b' and column 'B' is either 1 or 2
result1 = filter_instance.filter_data(conditions={'A': ['a', 'b'], 'B': [1, 2]})
print(result1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1124\3660475894.py in <module>
# ----> 1 filter_instance = Filter(df)
#       2
#       3 # Example 1: Filtering rows where column 'A' is either 'a' or 'b' and column 'B' is either 1 or 2
#       4 result1 = filter_instance.filter_data(conditions={'A': ['a', 'b'], 'B': [1, 2]})
#       5 print(result1)
#
# NameError: name 'Filter' is not defined
